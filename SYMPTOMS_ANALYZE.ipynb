# %% [markdown]
# <a href="https://colab.research.google.com/github/sarumathi03/Symptom-Analysis-ML-Project/blob/main/SYMPTOMS_ANALYZE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#This project is about symptom Analysis..
print("Symptoms Analysis for COVID-19")
# Out:
# Symptoms Analysis for COVID-19

# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib as plt
import sklearn
print("Libraries imported successfully")
# Out:
# Libraries imported successfully

# %%
# Code to read csv file into colaboratory:
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#2.1 Get the file
data = drive.CreateFile({'id':'1eAmmnrtNA7ox370kGWFVC9JzApcL9Qyn'}) # replace the id with id of file you want to access
data.GetContentFile('symptomsdata.csv')

# %%
#3.1 Read file as panda dataframe
# 1 represents Affected
# 0 represents Not Affected.
#Printing first 20 elements...
import pandas as pd
data= pd.read_csv('symptomsdata.csv') 
data.head(20)
# Out:
#     Fever  Tiredness  Dry-Cough  ...  Contact_No  Contact_Yes  Country
# 0       1          1          1  ...           0            1    China
# 1       1          1          1  ...           1            0    China
# 2       1          1          1  ...           0            0    China
# 3       1          1          1  ...           0            1    China
# 4       1          1          1  ...           1            0    China
# 5       1          1          1  ...           0            0    China
# 6       1          1          1  ...           0            1    China
# 7       1          1          1  ...           1            0    China
# 8       1          1          1  ...           0            0    China
# 9       1          1          1  ...           0            1    China
# 10      1          1          1  ...           1            0    China
# 11      1          1          1  ...           0            0    China
# ...

# %%
#Printing the last 25 elements..
data=pd.read_csv('symptomsdata.csv')
data.tail(25)
# Out:
#         Fever  Tiredness  Dry-Cough  ...  Contact_No  Contact_Yes  Country
# 316775      0          0          0  ...           0            0    Other
# 316776      0          0          0  ...           0            1    Other
# 316777      0          0          0  ...           1            0    Other
# 316778      0          0          0  ...           0            0    Other
# 316779      0          0          0  ...           0            1    Other
# 316780      0          0          0  ...           1            0    Other
# 316781      0          0          0  ...           0            0    Other
# 316782      0          0          0  ...           0            1    Other
# 316783      0          0          0  ...           1            0    Other
# 316784      0          0          0  ...           0            0    Other
# 316785      0          0          0  ...           0            1    Other
# ...

# %%
#Printing the statistical details...
print(data.describe())
# Out:
#                Fever      Tiredness  ...     Contact_No    Contact_Yes
# count  316800.000000  316800.000000  ...  316800.000000  316800.000000
# mean        0.312500       0.500000  ...       0.333333       0.333333
# std         0.463513       0.500001  ...       0.471405       0.471405
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.000000       0.000000  ...       0.000000       0.000000
# 50%         0.000000       0.500000  ...       0.000000       0.000000
# 75%         1.000000       1.000000  ...       1.000000       1.000000
# max         1.000000       1.000000  ...       1.000000       1.000000
#
# [8 rows x 26 columns]

# %%
#groupby function used..
# First grouping based on "Fever" 
# Within each team we are grouping based on "Difficulty-in-Breathing" 
import pandas as pd 
data = pd.read_csv("symptomsdata.csv") 
gk= data.groupby(['Fever', 'Difficulty-in-Breathing']) 
# Print the first value in each group 
gk.first()
# Out:
#                                Tiredness  Dry-Cough  ...  Contact_Yes  Country
# Fever Difficulty-in-Breathing                        ...
# 0     0                                1          1  ...            1    China
#       1                                1          1  ...            1    China
# 1     0                                1          1  ...            1    China
#       1                                1          1  ...            1    China
#
# [4 rows x 25 columns]

# %%
#printing unique Country names
print(data['Country'].unique())
# Out:
# ['China' 'Italy' 'Iran' 'Republic of Korean' 'France' 'Spain' 'Germany'
#  'UAE' 'Other-EUR' 'Other']

# %%
print(data.Tiredness)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 316795    0
# 316796    0
# 316797    0
# 316798    0
# 316799    0
# Name: Tiredness, Length: 316800, dtype: int64

# %%
#Printing rows,columns
print(data.shape)
# Out:
# (316800, 27)

# %%
#plotting the distribution of the Fever..
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Fever'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()                                  #In fever tested positive is low in such cases..

# %%
#Printing key values
print(data.keys())
# Out:
# Index(['Fever', 'Tiredness', 'Dry-Cough', 'Difficulty-in-Breathing',
#        'Sore-Throat', 'None_Sympton', 'Pains', 'Nasal-Congestion',
#        'Runny-Nose', 'Diarrhea', 'None_Experiencing', 'Age_0-9', 'Age_10-19',
#        'Age_20-24', 'Age_25-59', 'Age_60+', 'Gender_Female', 'Gender_Male',
#        'Gender_Transgender', 'Severity_Mild', 'Severity_Moderate',
#        'Severity_None', 'Severity_Severe', 'Contact_Dont-Know', 'Contact_No',
#        'Contact_Yes', 'Country'],
#       dtype='object')

# %%
#Printing the distribution of Dry-cough.
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Dry-Cough'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()   #In dry-cough tested positive is high in such cases..

# %%
#Printing the distribution of Nasal-congestion..
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Nasal-Congestion'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()    #In Nasal-Congestion tested positive is high in such cases..

# %%
#Printing data pains...
print(data.Pains)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 316795    0
# 316796    0
# 316797    0
# 316798    0
# 316799    0
# Name: Pains, Length: 316800, dtype: int64

# %%
#Printing the distribution of Diarrhea..
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Diarrhea'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()          #In Diarrhea tested positive is low in such cases..

# %%
#groupby function ...
import pandas as pd 
data = pd.read_csv("symptomsdata.csv") 
gk= data.groupby(['None_Sympton', 'None_Experiencing'])
gk.first()
# Out:
#                                 Fever  Tiredness  ...  Contact_Yes  Country
# None_Sympton None_Experiencing                    ...
# 0            0                      1          1  ...            1    China
#              1                      1          1  ...            1    China
# 1            0                      0          0  ...            1    China
#              1                      0          0  ...            1    China
#
# [4 rows x 25 columns]

# %%
#Printing the distribution of Age_25-59..
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Age_25-59'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()  #In Age_25-59 tested positive is low in such cases..

# %%
print(data.Gender_Male)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 316795    0
# 316796    0
# 316797    0
# 316798    0
# 316799    0
# Name: Gender_Male, Length: 316800, dtype: int64

# %%
print(data.Gender_Female)
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 316795    0
# 316796    0
# 316797    0
# 316798    0
# 316799    0
# Name: Gender_Female, Length: 316800, dtype: int64

# %%
#Plotting the distribution of Age_20-24..
import seaborn as sns
import matplotlib.pyplot as plt
fig,ax=plt.subplots()
fig.set_size_inches(5,5)
sns.countplot(data['Age_20-24'],label="count")
ax.set_xticklabels( ('Tested negative', 'Tested positive' ))
plt.show()    #In Age_20-24 tested positive is low in such cases..

# %%
#From that we have analysed, from which symptom test cases is  more positive..
print("Thank You")
# Out:
# Thank You
